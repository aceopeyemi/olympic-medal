# %%
import python as py
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("olympics_medals.csv", index_col=0, encoding='latin')

# %%
df.head()
# Out:
#             ioc_code   summer_participations summer_gold  summer_silver  \
# countries
# Afghanistan     (AFG)                     15           0              0
# Algeria         (ALG)                     14           5              4
# Argentina       (ARG)                     25          21             26
# Armenia         (ARM)                      7           2              8
# Australasia     (ANZ)                      2           3              4
#
#              summer_bronze summer_total  winter_participations  winter_gold  \
# countries
# Afghanistan              2            2                      0            0
# Algeria                  8           17                      3            0
# Argentina               30           77                     20            0
# Armenia                  8           18                      8            0
# Australasia              5           12                      0            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156 entries, Afghanistan to Mixed Team
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ioc_code               156 non-null    object
#  1   summer_participations  156 non-null    int64
#  2   summer_gold            156 non-null    object
#  3   summer_silver          156 non-null    int64
#  4   summer_bronze          156 non-null    int64
#  5   summer_total           156 non-null    object
#  6   winter_participations  156 non-null    int64
#  7   winter_gold            156 non-null    int64
#  8   winter_silver          156 non-null    int64
#  9   winter_bronze          156 non-null    int64
#  10  winter_total           156 non-null    int64
#  11  total_participation    156 non-null    int64
#  12  total_gold             156 non-null    object
#  13  total_silver           156 non-null    int64
# ...

# %%
df
# Out:
#                                   ioc_code   summer_participations  \
# countries
# Afghanistan                           (AFG)                     15
# Algeria                               (ALG)                     14
# Argentina                             (ARG)                     25
# Armenia                               (ARM)                      7
# Australasia                           (ANZ)                      2
# ...                                     ...                    ...
# Zambia                                (ZAM)                     14
# Zimbabwe                              (ZIM)                     14
# Independent Olympic Athletes          (IOA)                      3
# Independent Olympic Participants      (IOP)                      1
# Mixed Team                            (ZZX)                      3
#
#                                   summer_gold  summer_silver  summer_bronze  \
# countries
# ...

# %%
df.tail(20)
# Out:
#                                   ioc_code   summer_participations  \
# countries
# Tonga                                 (TGA)                     10
# Trinidad and Tobago                   (TTO)                     18
# Tunisia                               (TUN)                     15
# Turkey                                (TUR)                     23
# Turkmenistan                          (TKM)                      7
# Uganda                                (UGA)                     16
# Ukraine                               (UKR)                      7
# United Arab Emirates                  (UAE)                     10
# United States                         (USA)                     28
# Uruguay                               (URU)                     22
# Uzbekistan                            (UZB)                      7
# Venezuela                             (VEN)                     19
# Vietnam                               (VIE)                     16
# ...

# %%
df.shape
# Out:
# (156, 16)

# %%
df.describe()
# Out:
#        summer_participations  summer_silver  summer_bronze  \
# count             156.000000     156.000000     156.000000
# mean               14.673077      34.782051      37.775641
# std                 7.432417      86.085726      83.157105
# min                 0.000000       0.000000       0.000000
# 25%                 9.750000       1.000000       1.000000
# 50%                15.000000       5.000000       6.000000
# 75%                19.000000      29.250000      31.250000
# max                29.000000     831.000000     738.000000
#
#        winter_participations  winter_gold  winter_silver  winter_bronze  \
# count             156.000000    156.00000     156.000000     156.000000
# mean                7.314103      7.50641       7.487179       7.442308
# std                 7.900024     22.23264      21.431808      20.126773
# min                 0.000000      0.00000       0.000000       0.000000
# ...

# %%
nan_values = df.isna()
nan_columns = nan_values
nan_columns
# Out:
#                                    ioc_code   summer_participations  \
# countries
# Afghanistan                            False                  False
# Algeria                                False                  False
# Argentina                              False                  False
# Armenia                                False                  False
# Australasia                            False                  False
# ...                                      ...                    ...
# Zambia                                 False                  False
# Zimbabwe                               False                  False
# Independent Olympic Athletes           False                  False
# Independent Olympic Participants       False                  False
# Mixed Team                             False                  False
#
#                                    summer_gold  summer_silver  summer_bronze  \
# countries
# ...

# %%
nan_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156 entries, Afghanistan to Mixed Team
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ioc_code               156 non-null    bool
#  1   summer_participations  156 non-null    bool
#  2   summer_gold            156 non-null    bool
#  3   summer_silver          156 non-null    bool
#  4   summer_bronze          156 non-null    bool
#  5   summer_total           156 non-null    bool
#  6   winter_participations  156 non-null    bool
#  7   winter_gold            156 non-null    bool
#  8   winter_silver          156 non-null    bool
#  9   winter_bronze          156 non-null    bool
#  10  winter_total           156 non-null    bool
#  11  total_participation    156 non-null    bool
#  12  total_gold             156 non-null    bool
#  13  total_silver           156 non-null    bool
#  14  total_bronze           156 non-null    bool
# ...

# %%
df.isnull().sum()
# Out:
# ioc_code                 0
# summer_participations    0
# summer_gold              0
# summer_silver            0
# summer_bronze            0
# summer_total             0
# winter_participations    0
# winter_gold              0
# winter_silver            0
# winter_bronze            0
# winter_total             0
# total_participation      0
# total_gold               0
# total_silver             0
# total_bronze             0
# total_total              0
# dtype: int64
